# %% [markdown]
# # Financial Data Analysis

# %% [markdown]
# ## Importing and Exporting Stock Price Data from Yahoo Finance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = ["AAPL", "BA", "KO", "IBM", "DIS", "MSFT" ]

# %%
yf.download("AAPL", start="2010-01-01", end="2019-02-06")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2010-01-04   7.622500   7.660714   7.585000   7.643214   6.505279  493729600
# 2010-01-05   7.664286   7.699643   7.616071   7.656429   6.516526  601904800
# 2010-01-06   7.656429   7.686786   7.526786   7.534643   6.412874  552160000
# 2010-01-07   7.562500   7.571429   7.466071   7.520714   6.401016  477131200
# 2010-01-08   7.510714   7.571429   7.466429   7.570714   6.443574  447610800
# ...               ...        ...        ...        ...        ...        ...
# 2019-01-30  40.812500  41.537498  40.057499  41.312500  39.813030  244439200
# 2019-01-31  41.527500  42.250000  41.139999  41.610001  40.099743  162958400
# 2019-02-01  41.740002  42.244999  41.482498  41.630001  40.119007  130672400
# 2019-02-04  41.852501  42.915001  41.820000  42.812500  41.258583  125982000
# 2019-02-05  43.215000  43.770000  43.087502  43.544998  41.964500  144406400
#
# [2288 rows x 6 columns]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2019-02-06")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.505279  43.777534  27.933920  80.328064  18.936363  23.623899
# 2010-01-05  6.516528  45.211349  27.864235  79.357689  18.707298  23.631533
# 2010-01-06  6.412873  46.582802  27.716162  78.842163  18.700655  23.486511
# 2010-01-07  6.401019  48.468559  27.724874  78.569283  18.654182  23.242250
# 2010-01-08  6.443573  48.001022  27.768427  79.357689  18.308918  23.402542
#
#                Close                                    ...   Open  \
#                 AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
#                                                  Volume                      \
#                    IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.tail()
# Out:
#             Adj Close                                                 \
#                  AAPL          BA         DIS         IBM         KO
# Date
# 2019-01-30  39.813038  376.746277  108.800323  104.379593  41.913193
# 2019-01-31  40.099739  374.705719  110.173538  104.410667  42.149635
# 2019-02-01  40.119011  376.464478  109.956207  104.162125  42.648819
# 2019-02-04  41.258591  385.763641  110.450172  105.008759  43.130466
# 2019-02-05  41.964504  398.570618  111.299789  105.288406  43.139233
#
#                             Close                                      ...  \
#                   MSFT       AAPL          BA         DIS         IBM  ...
# Date                                                                   ...
# 2019-01-30  101.659241  41.312500  387.720001  110.129997  128.470367  ...
# 2019-01-31   99.795776  41.610001  385.619995  111.519997  128.508606  ...
# 2019-02-01   98.218987  41.630001  387.429993  111.300003  128.202682  ...
# 2019-02-04  101.047630  42.812500  397.000000  111.800003  129.244736  ...
# 2019-02-05  102.461960  43.544998  410.179993  112.660004  129.588913  ...
#
#                   Open                                        Volume  \
#                    DIS         IBM         KO        MSFT       AAPL
# Date
# 2019-01-30  110.300003  128.107071  47.250000  104.620003  244439200
# 2019-01-31  110.099998  128.537292  47.849998  103.800003  162958400
# 2019-02-01  111.970001  129.034424  48.480000  103.779999  130672400
# 2019-02-04  111.410004  128.126190  48.700001  102.870003  125982000
# 2019-02-05  112.019997  129.330780  49.330002  106.059998  144406400
#
#
#                   BA       DIS      IBM        KO      MSFT
# Date
# 2019-01-30  12705300   7853800  4707941  12952500  49471900
# 2019-01-31   6878500   8351600  5108664  32181500  55636400
# 2019-02-01   5625700   6557700  3981076  19130100  35535700
# 2019-02-04   4256600   7037000  4149064  15105700  31315100
# 2019-02-05   7230400  13619800  5647249  12651900  27325400
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2288 entries, 2010-01-04 to 2019-02-05
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2288 non-null   float64
#  1   (Adj Close, BA)    2288 non-null   float64
#  2   (Adj Close, DIS)   2288 non-null   float64
#  3   (Adj Close, IBM)   2288 non-null   float64
#  4   (Adj Close, KO)    2288 non-null   float64
#  5   (Adj Close, MSFT)  2288 non-null   float64
#  6   (Close, AAPL)      2288 non-null   float64
#  7   (Close, BA)        2288 non-null   float64
#  8   (Close, DIS)       2288 non-null   float64
#  9   (Close, IBM)       2288 non-null   float64
#  10  (Close, KO)        2288 non-null   float64
#  11  (Close, MSFT)      2288 non-null   float64
#  12  (High, AAPL)       2288 non-null   float64
#  13  (High, BA)         2288 non-null   float64
#  14  (High, DIS)        2288 non-null   float64
#  15  (High, IBM)        2288 non-null   float64
#  16  (High, KO)         2288 non-null   float64
#  17  (High, MSFT)       2288 non-null   float64
#  18  (Low, AAPL)        2288 non-null   float64
#  19  (Low, BA)          2288 non-null   float64
#  20  (Low, DIS)         2288 non-null   float64
#  21  (Low, IBM)         2288 non-null   float64
#  22  (Low, KO)          2288 non-null   float64
#  23  (Low, MSFT)        2288 non-null   float64
#  24  (Open, AAPL)       2288 non-null   float64
#  25  (Open, BA)         2288 non-null   float64
#  26  (Open, DIS)        2288 non-null   float64
#  27  (Open, IBM)        2288 non-null   float64
#  28  (Open, KO)         2288 non-null   float64
#  29  (Open, MSFT)       2288 non-null   float64
#  30  (Volume, AAPL)     2288 non-null   int64
#  31  (Volume, BA)       2288 non-null   int64
#  32  (Volume, DIS)      2288 non-null   int64
#  33  (Volume, IBM)      2288 non-null   int64
#  34  (Volume, KO)       2288 non-null   int64
#  35  (Volume, MSFT)     2288 non-null   int64
# dtypes: float64(30), int64(6)
# memory usage: 661.4 KB

# %%
stocks.to_csv("stocks.csv")

# %%
stocks = pd.read_csv("stocks.csv", header = [0, 1], index_col = [0], parse_dates = [0])

# %%
pd.read_csv("stocks.csv").head()
# Out:
#    Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0         NaN                AAPL                  BA                 DIS
# 1        Date                 NaN                 NaN                 NaN
# 2  2010-01-04   6.505279064178467   43.77753448486328   27.93391990661621
# 3  2010-01-05  6.5165276527404785   45.21134948730469  27.864234924316406
# 4  2010-01-06   6.412872791290283  46.582801818847656  27.716161727905273
#
#          Adj Close.3         Adj Close.4         Adj Close.5  \
# 0                IBM                  KO                MSFT
# 1                NaN                 NaN                 NaN
# 2  80.32806396484375  18.936363220214844  23.623899459838867
# 3   79.3576889038086  18.707298278808594  23.631532669067383
# 4   78.8421630859375  18.700654983520508   23.48651123046875
#
#                Close             Close.1             Close.2  ...  \
# 0               AAPL                  BA                 DIS  ...
# 1                NaN                 NaN                 NaN  ...
# 2  7.643214225769043   56.18000030517578   32.06999969482422  ...
# 3  7.656428813934326   58.02000045776367  31.989999771118164  ...
# 4  7.534643173217773  59.779998779296875   31.81999969482422  ...
#
#                Open.2              Open.3              Open.4  \
# 0                 DIS                 IBM                  KO
# 1                 NaN                 NaN                 NaN
# 2                32.5  125.41108703613281  28.579999923706055
# 3   32.06999969482422  125.88909912109375  28.424999237060547
# 4  31.899999618530273  124.93307495117188  28.174999237060547
#
#                Open.5     Volume Volume.1  Volume.2 Volume.3  Volume.4  \
# 0                MSFT       AAPL       BA       DIS      IBM        KO
# 1                 NaN        NaN      NaN       NaN      NaN       NaN
# 2    30.6200008392334  493729600  6186700  13700400  6438444  13870400
# 3  30.850000381469727  601904800  8867800  10307700  7156104  23172400
# 4    30.8799991607666  552160000  8836500  10709500  5863144  19264600
#
#    Volume.5
# 0      MSFT
# 1       NaN
# 2  38409100
# 3  49749600
# 4  58182400
#
# [5 rows x 37 columns]

# %%
pd.read_csv("stocks.csv",header=[0,1]).head()
# Out:
#   Unnamed: 0_level_0 Adj Close                                              \
#   Unnamed: 0_level_1      AAPL         BA        DIS        IBM         KO
# 0               Date       NaN        NaN        NaN        NaN        NaN
# 1         2010-01-04  6.505279  43.777534  27.933920  80.328064  18.936363
# 2         2010-01-05  6.516528  45.211349  27.864235  79.357689  18.707298
# 3         2010-01-06  6.412873  46.582802  27.716162  78.842163  18.700655
# 4         2010-01-07  6.401019  48.468559  27.724874  78.569283  18.654182
#
#                  Close                    ...   Open                         \
#         MSFT      AAPL         BA    DIS  ...    DIS         IBM         KO
# 0        NaN       NaN        NaN    NaN  ...    NaN         NaN        NaN
# 1  23.623899  7.643214  56.180000  32.07  ...  32.50  125.411087  28.580000
# 2  23.631533  7.656429  58.020000  31.99  ...  32.07  125.889099  28.424999
# 3  23.486511  7.534643  59.779999  31.82  ...  31.90  124.933075  28.174999
# 4  23.242250  7.520714  62.200001  31.83  ...  31.77  124.158699  28.165001
#
#                    Volume                                                 \
#         MSFT         AAPL          BA         DIS        IBM          KO
# 0        NaN          NaN         NaN         NaN        NaN         NaN
# 1  30.620001  493729600.0   6186700.0  13700400.0  6438444.0  13870400.0
# 2  30.850000  601904800.0   8867800.0  10307700.0  7156104.0  23172400.0
# 3  30.879999  552160000.0   8836500.0  10709500.0  5863144.0  19264600.0
# 4  30.629999  477131200.0  14379100.0   8202100.0  6109268.0  13234600.0
#
#
#          MSFT
# 0         NaN
# 1  38409100.0
# 2  49749600.0
# 3  58182400.0
# 4  50559700.0
#
# [5 rows x 37 columns]

# %%
pd.read_csv("stocks.csv",header=[0,1], index_col= [0]).head() # 0번째 column을 Index로 지정
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.505279  43.777534  27.933920  80.328064  18.936363  23.623899
# 2010-01-05  6.516528  45.211349  27.864235  79.357689  18.707298  23.631533
# 2010-01-06  6.412873  46.582802  27.716162  78.842163  18.700655  23.486511
# 2010-01-07  6.401019  48.468559  27.724874  78.569283  18.654182  23.242250
# 2010-01-08  6.443573  48.001022  27.768427  79.357689  18.308918  23.402542
#
#                Close                                    ...   Open  \
#                 AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
#                                                  Volume                      \
#                    IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.505279  43.777534  27.933920  80.328064  18.936363  23.623899
# 2010-01-05  6.516528  45.211349  27.864235  79.357689  18.707298  23.631533
# 2010-01-06  6.412873  46.582802  27.716162  78.842163  18.700655  23.486511
# 2010-01-07  6.401019  48.468559  27.724874  78.569283  18.654182  23.242250
# 2010-01-08  6.443573  48.001022  27.768427  79.357689  18.308918  23.402542
#
#                Close                                    ...   Open  \
#                 AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
#                                                  Volume                      \
#                    IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.columns = stocks.columns.to_flat_index() # multi-index를 tuple의 집합으로 변경

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'BA'),  ('Adj Close', 'DIS'),
#         ('Adj Close', 'IBM'),   ('Adj Close', 'KO'), ('Adj Close', 'MSFT'),
#            ('Close', 'AAPL'),       ('Close', 'BA'),      ('Close', 'DIS'),
#             ('Close', 'IBM'),       ('Close', 'KO'),     ('Close', 'MSFT'),
#             ('High', 'AAPL'),        ('High', 'BA'),       ('High', 'DIS'),
#              ('High', 'IBM'),        ('High', 'KO'),      ('High', 'MSFT'),
#              ('Low', 'AAPL'),         ('Low', 'BA'),        ('Low', 'DIS'),
#               ('Low', 'IBM'),         ('Low', 'KO'),       ('Low', 'MSFT'),
#             ('Open', 'AAPL'),        ('Open', 'BA'),       ('Open', 'DIS'),
#              ('Open', 'IBM'),        ('Open', 'KO'),      ('Open', 'MSFT'),
#           ('Volume', 'AAPL'),      ('Volume', 'BA'),     ('Volume', 'DIS'),
#            ('Volume', 'IBM'),      ('Volume', 'KO'),    ('Volume', 'MSFT')],
#       dtype='object')

# %%
stocks.head()
# Out:
#             (Adj Close, AAPL)  (Adj Close, BA)  (Adj Close, DIS)  \
# Date
# 2010-01-04           6.505279        43.777534         27.933920
# 2010-01-05           6.516528        45.211349         27.864235
# 2010-01-06           6.412873        46.582802         27.716162
# 2010-01-07           6.401019        48.468559         27.724874
# 2010-01-08           6.443573        48.001022         27.768427
#
#             (Adj Close, IBM)  (Adj Close, KO)  (Adj Close, MSFT)  \
# Date
# 2010-01-04         80.328064        18.936363          23.623899
# 2010-01-05         79.357689        18.707298          23.631533
# 2010-01-06         78.842163        18.700655          23.486511
# 2010-01-07         78.569283        18.654182          23.242250
# 2010-01-08         79.357689        18.308918          23.402542
#
#             (Close, AAPL)  (Close, BA)  (Close, DIS)  (Close, IBM)  ...  \
# Date                                                                ...
# 2010-01-04       7.643214    56.180000     32.070000    126.625237  ...
# 2010-01-05       7.656429    58.020000     31.990000    125.095604  ...
# 2010-01-06       7.534643    59.779999     31.820000    124.282982  ...
# 2010-01-07       7.520714    62.200001     31.830000    123.852776  ...
# 2010-01-08       7.570714    61.599998     31.879999    125.095604  ...
#
#             (Open, DIS)  (Open, IBM)  (Open, KO)  (Open, MSFT)  \
# Date
# 2010-01-04        32.50   125.411087   28.580000     30.620001
# 2010-01-05        32.07   125.889099   28.424999     30.850000
# 2010-01-06        31.90   124.933075   28.174999     30.879999
# 2010-01-07        31.77   124.158699   28.165001     30.629999
# 2010-01-08        31.66   123.393883   27.730000     30.280001
#
#             (Volume, AAPL)  (Volume, BA)  (Volume, DIS)  (Volume, IBM)  \
# Date
# 2010-01-04       493729600       6186700       13700400        6438444
# 2010-01-05       601904800       8867800       10307700        7156104
# 2010-01-06       552160000       8836500       10709500        5863144
# 2010-01-07       477131200      14379100        8202100        6109268
# 2010-01-08       447610800       7146600        7657500        4390271
#
#             (Volume, KO)  (Volume, MSFT)
# Date
# 2010-01-04      13870400        38409100
# 2010-01-05      23172400        49749600
# 2010-01-06      19264600        58182400
# 2010-01-07      13234600        50559700
# 2010-01-08      28712400        51197400
#
# [5 rows x 36 columns]

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns) # 다시 돌리기

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.505279  43.777534  27.933920  80.328064  18.936363  23.623899
# 2010-01-05  6.516528  45.211349  27.864235  79.357689  18.707298  23.631533
# 2010-01-06  6.412873  46.582802  27.716162  78.842163  18.700655  23.486511
# 2010-01-07  6.401019  48.468559  27.724874  78.569283  18.654182  23.242250
# 2010-01-08  6.443573  48.001022  27.768427  79.357689  18.308918  23.402542
#
#                Close                                    ...   Open  \
#                 AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
#                                                  Volume                      \
#                    IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.swaplevel(axis = 1).sort_index(axis = 1).head() # 종목별로 sorting (하위 feature로 정렬)
# Out:
#                 AAPL                                                     \
#            Adj Close     Close      High       Low      Open     Volume
# Date
# 2010-01-04  6.505279  7.643214  7.660714  7.585000  7.622500  493729600
# 2010-01-05  6.516528  7.656429  7.699643  7.616071  7.664286  601904800
# 2010-01-06  6.412873  7.534643  7.686786  7.526786  7.656429  552160000
# 2010-01-07  6.401019  7.520714  7.571429  7.466071  7.562500  477131200
# 2010-01-08  6.443573  7.570714  7.571429  7.466429  7.510714  447610800
#
#                    BA                                   ...         KO  \
#             Adj Close      Close       High        Low  ...       High
# Date                                                    ...
# 2010-01-04  43.777534  56.180000  56.389999  54.799999  ...  28.610001
# 2010-01-05  45.211349  58.020000  58.279999  56.000000  ...  28.495001
# 2010-01-06  46.582802  59.779999  59.990002  57.880001  ...  28.219999
# 2010-01-07  48.468559  62.200001  62.310001  59.020000  ...  28.184999
# 2010-01-08  48.001022  61.599998  61.779999  60.860001  ...  27.820000
#
#                                                  MSFT                        \
#                   Low       Open    Volume  Adj Close      Close       High
# Date
# 2010-01-04  28.450001  28.580000  13870400  23.623899  30.950001  31.100000
# 2010-01-05  28.070000  28.424999  23172400  23.631533  30.959999  31.100000
# 2010-01-06  27.990000  28.174999  19264600  23.486511  30.770000  31.080000
# 2010-01-07  27.875000  28.165001  13234600  23.242250  30.450001  30.700001
# 2010-01-08  27.375000  27.730000  28712400  23.402542  30.660000  30.879999
#
#
#                   Low       Open    Volume
# Date
# 2010-01-04  30.590000  30.620001  38409100
# 2010-01-05  30.639999  30.850000  49749600
# 2010-01-06  30.520000  30.879999  58182400
# 2010-01-07  30.190001  30.629999  50559700
# 2010-01-08  30.240000  30.280001  51197400
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Initial Inspection and Visualization

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0])

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.505279  43.777534  27.933920  80.328064  18.936363  23.623899
# 2010-01-05  6.516528  45.211349  27.864235  79.357689  18.707298  23.631533
# 2010-01-06  6.412873  46.582802  27.716162  78.842163  18.700655  23.486511
# 2010-01-07  6.401019  48.468559  27.724874  78.569283  18.654182  23.242250
# 2010-01-08  6.443573  48.001022  27.768427  79.357689  18.308918  23.402542
#
#                Close                                    ...   Open  \
#                 AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
#                                                  Volume                      \
#                    IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.tail()
# Out:
#             Adj Close                                                 \
#                  AAPL          BA         DIS         IBM         KO
# Date
# 2019-01-30  39.813038  376.746277  108.800323  104.379593  41.913193
# 2019-01-31  40.099739  374.705719  110.173538  104.410667  42.149635
# 2019-02-01  40.119011  376.464478  109.956207  104.162125  42.648819
# 2019-02-04  41.258591  385.763641  110.450172  105.008759  43.130466
# 2019-02-05  41.964504  398.570618  111.299789  105.288406  43.139233
#
#                             Close                                      ...  \
#                   MSFT       AAPL          BA         DIS         IBM  ...
# Date                                                                   ...
# 2019-01-30  101.659241  41.312500  387.720001  110.129997  128.470367  ...
# 2019-01-31   99.795776  41.610001  385.619995  111.519997  128.508606  ...
# 2019-02-01   98.218987  41.630001  387.429993  111.300003  128.202682  ...
# 2019-02-04  101.047630  42.812500  397.000000  111.800003  129.244736  ...
# 2019-02-05  102.461960  43.544998  410.179993  112.660004  129.588913  ...
#
#                   Open                                        Volume  \
#                    DIS         IBM         KO        MSFT       AAPL
# Date
# 2019-01-30  110.300003  128.107071  47.250000  104.620003  244439200
# 2019-01-31  110.099998  128.537292  47.849998  103.800003  162958400
# 2019-02-01  111.970001  129.034424  48.480000  103.779999  130672400
# 2019-02-04  111.410004  128.126190  48.700001  102.870003  125982000
# 2019-02-05  112.019997  129.330780  49.330002  106.059998  144406400
#
#
#                   BA       DIS      IBM        KO      MSFT
# Date
# 2019-01-30  12705300   7853800  4707941  12952500  49471900
# 2019-01-31   6878500   8351600  5108664  32181500  55636400
# 2019-02-01   5625700   6557700  3981076  19130100  35535700
# 2019-02-04   4256600   7037000  4149064  15105700  31315100
# 2019-02-05   7230400  13619800  5647249  12651900  27325400
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Adj Close(조정 종가)는 배당금과 주식 분할을 포함하고 있어서 시세 차익 뿐만 아니라 총 수익을 결정하는 데 있어 더 나은 측정 기준이 된다.
#Volumn => 거래량
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2288 entries, 2010-01-04 to 2019-02-05
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2288 non-null   float64
#  1   (Adj Close, BA)    2288 non-null   float64
#  2   (Adj Close, DIS)   2288 non-null   float64
#  3   (Adj Close, IBM)   2288 non-null   float64
#  4   (Adj Close, KO)    2288 non-null   float64
#  5   (Adj Close, MSFT)  2288 non-null   float64
#  6   (Close, AAPL)      2288 non-null   float64
#  7   (Close, BA)        2288 non-null   float64
#  8   (Close, DIS)       2288 non-null   float64
#  9   (Close, IBM)       2288 non-null   float64
#  10  (Close, KO)        2288 non-null   float64
#  11  (Close, MSFT)      2288 non-null   float64
#  12  (High, AAPL)       2288 non-null   float64
#  13  (High, BA)         2288 non-null   float64
#  14  (High, DIS)        2288 non-null   float64
#  15  (High, IBM)        2288 non-null   float64
#  16  (High, KO)         2288 non-null   float64
#  17  (High, MSFT)       2288 non-null   float64
#  18  (Low, AAPL)        2288 non-null   float64
#  19  (Low, BA)          2288 non-null   float64
#  20  (Low, DIS)         2288 non-null   float64
#  21  (Low, IBM)         2288 non-null   float64
#  22  (Low, KO)          2288 non-null   float64
#  23  (Low, MSFT)        2288 non-null   float64
#  24  (Open, AAPL)       2288 non-null   float64
#  25  (Open, BA)         2288 non-null   float64
#  26  (Open, DIS)        2288 non-null   float64
#  27  (Open, IBM)        2288 non-null   float64
#  28  (Open, KO)         2288 non-null   float64
#  29  (Open, MSFT)       2288 non-null   float64
#  30  (Volume, AAPL)     2288 non-null   int64
#  31  (Volume, BA)       2288 non-null   int64
#  32  (Volume, DIS)      2288 non-null   int64
#  33  (Volume, IBM)      2288 non-null   int64
#  34  (Volume, KO)       2288 non-null   int64
#  35  (Volume, MSFT)     2288 non-null   int64
# dtypes: float64(30), int64(6)
# memory usage: 661.4 KB

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AAPL           BA          DIS          IBM           KO
# count  2288.000000  2288.000000  2288.000000  2288.000000  2288.000000
# mean     22.802651   130.186519    71.644731   110.167901    30.298716
# std      11.616604    88.687439    29.810688    14.712385     6.391489
# min       5.837761    43.777534    25.536150    74.226868    16.761829
# 25%      13.388201    60.522998    38.754961   102.912912    25.955496
# 50%      21.255657   111.242416    79.027557   112.005913    30.847905
# 75%      28.659925   135.417168    99.533253   121.640718    35.154795
# max      55.717308   398.570618   116.560318   138.501801    44.137581
#
#                           Close                                         ...  \
#               MSFT         AAPL           BA          DIS          IBM  ...
# count  2288.000000  2288.000000  2288.000000  2288.000000  2288.000000  ...
# mean     43.178018    25.010675   144.103820    76.582640   157.148967  ...
# std      24.647599    11.723928    88.320854    29.829775    23.090712  ...
# min      17.725109     6.858929    56.180000    29.000000   102.839386  ...
# 25%      23.152594    15.426250    73.755001    43.477500   139.569794  ...
# 50%      36.102074    23.747499   127.639999    85.869999   154.923515  ...
# 75%      53.654158    31.697500   152.267502   104.220001   177.746178  ...
# max     110.004433    58.017502   410.179993   121.690002   206.309753  ...
#
#               Open                                               Volume  \
#                DIS          IBM           KO         MSFT          AAPL
# count  2288.000000  2288.000000  2288.000000  2288.000000  2.288000e+03
# mean     76.578059   157.093598    39.371628    48.656967  3.187215e+08
# std      29.861050    23.077858     5.565342    24.466094  2.380917e+08
# min      28.730000   103.250481    25.110001    23.090000  4.590360e+07
# 25%      43.492500   139.586521    36.186249    28.965000  1.371571e+08
# 50%      86.084999   154.875717    40.695000    41.610001  2.497872e+08
# 75%     104.230003   177.449814    43.322500    58.722501  4.298973e+08
# max     121.500000   205.908218    50.820000   115.419998  1.880998e+09
#
#
#                  BA           DIS           IBM            KO          MSFT
# count  2.288000e+03  2.288000e+03  2.288000e+03  2.288000e+03  2.288000e+03
# mean   4.601274e+06  8.775748e+06  5.025515e+06  1.503227e+07  4.155095e+07
# std    2.440871e+06  4.907867e+06  2.643450e+06  6.574772e+06  2.339253e+07
# min    7.889000e+05  2.165700e+06  1.247878e+06  2.996300e+06  7.425600e+06
# 25%    3.110000e+06  6.053675e+06  3.462156e+06  1.082630e+07  2.590040e+07
# 50%    4.091200e+06  7.602750e+06  4.357636e+06  1.355170e+07  3.600365e+07
# 75%    5.332025e+06  9.948850e+06  5.648164e+06  1.755170e+07  5.160548e+07
# max    4.439180e+07  8.704850e+07  3.189275e+07  9.896750e+07  3.193179e+08
#
# [8 rows x 36 columns]

# %%
close = stocks.loc[:, "Close"].copy() # 종가만 slicing

# %%
close.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT
# Date
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  27.575001  30.660000

# %%
close.tail()
# Out:
#                  AAPL          BA         DIS         IBM         KO  \
# Date
# 2019-01-30  41.312500  387.720001  110.129997  128.470367  47.860001
# 2019-01-31  41.610001  385.619995  111.519997  128.508606  48.130001
# 2019-02-01  41.630001  387.429993  111.300003  128.202682  48.700001
# 2019-02-04  42.812500  397.000000  111.800003  129.244736  49.250000
# 2019-02-05  43.544998  410.179993  112.660004  129.588913  49.259998
#
#                   MSFT
# Date
# 2019-01-30  106.379997
# 2019-01-31  104.430000
# 2019-02-01  102.779999
# 2019-02-04  105.739998
# 2019-02-05  107.220001

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# /var/folders/k8/xm42xp_16cs6fgtvp6ymr9l40000gn/T/ipykernel_17292/2470400703.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## Normalizing Time Series to a Base Value (100)

# %%
close.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT
# Date
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  27.575001  30.660000

# %%
close.iloc[0,0] # 첫항으로 나머지 값들을 다 나눈다.
# Out:
# 7.643214225769043

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# basevalue를 100으로 조정
# 첫항으로 나머지 값들을 다 나눈다.
# Out:
# Date
# 2010-01-04    100.000000
# 2010-01-05    100.172893
# 2010-01-06     98.579511
# 2010-01-07     98.397266
# 2010-01-08     99.051443
#                  ...
# 2019-01-30    540.512130
# 2019-01-31    544.404479
# 2019-02-01    544.666155
# 2019-02-04    560.137381
# 2019-02-05    569.721022
# Name: AAPL, Length: 2288, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# BA       56.180000
# DIS      32.070000
# IBM     126.625237
# KO       28.520000
# MSFT     30.950001
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm.head() # 모든 값 각 종목의 첫 주가로 정규화
# Out:
#                   AAPL          BA         DIS         IBM          KO  \
# Date
# 2010-01-04  100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-05  100.172893  103.275187   99.750546   98.792000   98.790318
# 2010-01-06   98.579511  106.407972   99.220455   98.150247   98.755261
# 2010-01-07   98.397266  110.715558   99.251638   97.810499   98.509814
# 2010-01-08   99.051443  109.647558   99.407544   98.792000   96.686537
#
#                   MSFT
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.032305
# 2010-01-06   99.418416
# 2010-01-07   98.384491
# 2010-01-08   99.063002

# %%
norm.tail()
# Out:
#                   AAPL          BA         DIS         IBM          KO  \
# Date
# 2019-01-30  540.512130  690.138838  343.405046  101.457159  167.812061
# 2019-01-31  544.404479  686.400842  347.739313  101.487357  168.758767
# 2019-02-01  544.666155  689.622625  347.053334  101.245760  170.757363
# 2019-02-04  560.137381  706.657170  348.612423  102.068702  172.685832
# 2019-02-05  569.721022  730.117463  351.294059  102.340510  172.720889
#
#                   MSFT
# Date
# 2019-01-30  343.715653
# 2019-01-31  337.415178
# 2019-02-01  332.083994
# 2019-02-04  341.647804
# 2019-02-05  346.429721

# %%
# 개별 주가에 대한 등락을 더 잘 비교할 수 있다.
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## The shift() method

# %%
close.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT
# Date
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  27.575001  30.660000

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
aapl.shift(periods = 1).head() # 1 timestep 만큼 shift한다.
# Out:
#                 AAPL
# Date
# 2010-01-04       NaN
# 2010-01-05  7.643214
# 2010-01-06  7.656429
# 2010-01-07  7.534643
# 2010-01-08  7.520714

# %%
aapl["lag1"] = aapl.shift(periods = 1)
aapl.head()
# Out:
#                 AAPL      lag1
# Date
# 2010-01-04  7.643214       NaN
# 2010-01-05  7.656429  7.643214
# 2010-01-06  7.534643  7.656429
# 2010-01-07  7.520714  7.534643
# 2010-01-08  7.570714  7.520714

# %%
aapl["lag1"].shift(periods = -1) # 복구
# Out:
# Date
# 2010-01-04     7.643214
# 2010-01-05     7.656429
# 2010-01-06     7.534643
# 2010-01-07     7.520714
# 2010-01-08     7.570714
#                 ...
# 2019-01-30    41.312500
# 2019-01-31    41.610001
# 2019-02-01    41.630001
# 2019-02-04    42.812500
# 2019-02-05          NaN
# Name: lag1, Length: 2288, dtype: float64

# %%
aapl.AAPL.sub(aapl.lag1) # 차분
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.013215
# 2010-01-06   -0.121786
# 2010-01-07   -0.013929
# 2010-01-08    0.050000
#                 ...
# 2019-01-30    2.642502
# 2019-01-31    0.297501
# 2019-02-01    0.020000
# 2019-02-04    1.182499
# 2019-02-05    0.732498
# Length: 2288, dtype: float64

# %%
aapl["Diff"] = aapl.AAPL.sub  (aapl.lag1) # AAPL - lag1
aapl.head()
# Out:
#                 AAPL      lag1      Diff
# Date
# 2010-01-04  7.643214       NaN       NaN
# 2010-01-05  7.656429  7.643214  0.013215
# 2010-01-06  7.534643  7.656429 -0.121786
# 2010-01-07  7.520714  7.534643 -0.013929
# 2010-01-08  7.570714  7.520714  0.050000

# %%
aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.172893
# 2010-01-06   -1.590632
# 2010-01-07   -0.184871
# 2010-01-08    0.664833
#                 ...
# 2019-01-30    6.833468
# 2019-01-31    0.720123
# 2019-02-01    0.048066
# 2019-02-04    2.840497
# 2019-02-05    1.710945
# Length: 2288, dtype: float64

# %%
aapl["pct_change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871
# 2010-01-08  7.570714  7.520714  0.050000    0.664833

# %% [markdown]
# ## The methods diff() and pct_change()

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871
# 2010-01-08  7.570714  7.520714  0.050000    0.664833

# %%
aapl.AAPL.diff(periods = 2)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05         NaN
# 2010-01-06   -0.108571
# 2010-01-07   -0.135715
# 2010-01-08    0.036071
#                 ...
# 2019-01-30    2.237499
# 2019-01-31    2.940002
# 2019-02-01    0.317501
# 2019-02-04    1.202499
# 2019-02-05    1.914997
# Name: AAPL, Length: 2288, dtype: float64

# %%
aapl["Diff2"] = aapl.AAPL.diff(periods = 1)
aapl.head(10)
# Out:
#                 AAPL      lag1      Diff  pct_change     Diff2
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN       NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893  0.013215
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632 -0.121786
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871 -0.013929
# 2010-01-08  7.570714  7.520714  0.050000    0.664833  0.050000
# 2010-01-11  7.503929  7.570714 -0.066785   -0.882147 -0.066785
# 2010-01-12  7.418571  7.503929 -0.085358   -1.137513 -0.085358
# 2010-01-13  7.523214  7.418571  0.104643    1.410553  0.104643
# 2010-01-14  7.479643  7.523214 -0.043571   -0.579154 -0.043571
# 2010-01-15  7.354643  7.479643 -0.125000   -1.671203 -0.125000

# %%
aapl.Diff.equals(aapl.Diff2)
# Out:
# True

# %%
aapl["pct_change2"] = aapl.AAPL.pct_change(periods = 1).mul(100)
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change     Diff2  pct_change2
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN       NaN          NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893  0.013215     0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632 -0.121786    -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871 -0.013929    -0.184871
# 2010-01-08  7.570714  7.520714  0.050000    0.664833  0.050000     0.664833

# %%
aapl.AAPL.resample("BM").last()#.pct_change(periods =1).mul(100)
# Out:
# Date
# 2010-01-29     6.859286
# 2010-02-26     7.307857
# 2010-03-31     8.392857
# 2010-04-30     9.324643
# 2010-05-31     9.174286
#                 ...
# 2018-10-31    54.715000
# 2018-11-30    44.645000
# 2018-12-31    39.435001
# 2019-01-31    41.610001
# 2019-02-28    43.544998
# Freq: BM, Name: AAPL, Length: 110, dtype: float64

# %%
aapl.AAPL.resample("BM").last().pct_change(periods =1).mul(100) # 월수익률
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2018-10-31    -3.047756
# 2018-11-30   -18.404459
# 2018-12-31   -11.669838
# 2019-01-31     5.515403
# 2019-02-28     4.650319
# Freq: BM, Name: AAPL, Length: 110, dtype: float64

# %% [markdown]
# ## Measuring Stock Perfromance with MEAN Return and STD of Returns

# %%
import numpy as np

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
aapl.pct_change().dropna() # 첫번째 NaN 값 제거
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2019-01-30  0.068335
# 2019-01-31  0.007201
# 2019-02-01  0.000481
# 2019-02-04  0.028405
# 2019-02-05  0.017109
#
# [2287 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()
ret.head()
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2287 entries, 2010-01-05 to 2019-02-05
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2287 non-null   float64
# dtypes: float64(1)
# memory usage: 35.7 KB

# %%
ret.plot(kind = "hist", figsize = (12 ,8), bins = 100)
plt.show()

# %%
daily_mean_Return = ret.mean() # 일일 평균 수익
daily_mean_Return
# Out:
# AAPL    0.000896
# dtype: float64

# %%
var_daily_Returns = ret.var()
var_daily_Returns
# Out:
# AAPL    0.000269
# dtype: float64

# %%
std_daily_Returns = np.sqrt(var_daily_Returns)
std_daily_Returns
# Out:
# AAPL    0.016394
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.016394
# dtype: float64

# %%
ann_mean_Return = ret.mean() * 252 # 주말을 제외한 실제 장이 열린 날 - 252일
ann_mean_Return # 연간 평균 수익률
# Out:
# AAPL    0.225708
# dtype: float64

# %%
ann_var_Returns = ret.var() * 252
ann_var_Returns # 연간 변동성은 더 크다.
# Out:
# AAPL    0.067732
# dtype: float64

# %%
ann_std_Returns = np.sqrt(ann_var_Returns)
ann_std_Returns # 연간 표준편차
# Out:
# AAPL    0.260254
# dtype: float64

# %%
ret.std() * np.sqrt(252)
# Out:
# AAPL    0.260254
# dtype: float64

# %% [markdown]
# ## Financial Time Series - Return and Risk

# %%
import numpy as np

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT
# Date
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  27.575001  30.660000

# %%
close.pct_change().dropna()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.040482  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006897
# 2010-01-11 -0.008821 -0.011851 -0.016311 -0.010470  0.020308 -0.012720
# ...              ...       ...       ...       ...       ...       ...
# 2019-01-30  0.068335  0.062509 -0.006943  0.000372  0.009705  0.033417
# 2019-01-31  0.007201 -0.005416  0.012621  0.000298  0.005641 -0.018330
# 2019-02-01  0.000481  0.004694 -0.001973 -0.002381  0.011843 -0.015800
# 2019-02-04  0.028405  0.024701  0.004492  0.008128  0.011294  0.028799
# 2019-02-05  0.017109  0.033199  0.007692  0.002663  0.000203  0.013997
#
# [2287 rows x 6 columns]

# %%
ret = close.pct_change().dropna()

# %%
ret.head()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.040482  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006897
# 2010-01-11 -0.008821 -0.011851 -0.016311 -0.010470  0.020308 -0.012720

# %%
ret.describe()
# Out:
#               AAPL           BA          DIS          IBM           KO  \
# count  2287.000000  2287.000000  2287.000000  2287.000000  2287.000000
# mean      0.000896     0.000990     0.000636     0.000088     0.000281
# std       0.016394     0.015488     0.013139     0.012429     0.009207
# min      -0.123558    -0.089290    -0.091708    -0.082790    -0.060291
# 25%      -0.007070    -0.007180    -0.005795    -0.005999    -0.004522
# 50%       0.000759     0.001100     0.000755     0.000213     0.000441
# 75%       0.009667     0.009380     0.007530     0.006392     0.005465
# max       0.088741     0.098795     0.076302     0.088645     0.056872
#
#               MSFT
# count  2287.000000
# mean      0.000650
# std       0.014579
# min      -0.113995
# 25%      -0.006901
# 50%       0.000354
# 75%       0.008078
# max       0.104522

# %%
ret.describe().T.loc[:, ["mean", "std"]] # transpose 후 mean과 std column만 추출
# Out:
#           mean       std
# AAPL  0.000896  0.016394
# BA    0.000990  0.015488
# DIS   0.000636  0.013139
# IBM   0.000088  0.012429
# KO    0.000281  0.009207
# MSFT  0.000650  0.014579

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.000896  0.016394
# BA    0.000990  0.015488
# DIS   0.000636  0.013139
# IBM   0.000088  0.012429
# KO    0.000281  0.009207
# MSFT  0.000650  0.014579

# %%
# 연간 수익률 & 표준편차
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"] * np.sqrt(252)

# %%
summary # 수익률 & 리스크
# Out:
#           mean       std
# AAPL  0.225708  0.260254
# BA    0.249376  0.245871
# DIS   0.160287  0.208570
# IBM   0.022081  0.197310
# KO    0.070923  0.146161
# MSFT  0.163698  0.231440

# %%
summary.plot(kind = "scatter", x = "std", y = "mean", figsize = (10,7), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# ## Financial Time Series - Covariance and Correlation

# %%
ret.head()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.040482  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006897
# 2010-01-11 -0.008821 -0.011851 -0.016311 -0.010470  0.020308 -0.012720

# %%
ret.cov()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT
# AAPL  0.000269  0.000104  0.000080  0.000076  0.000040  0.000107
# BA    0.000104  0.000240  0.000105  0.000088  0.000057  0.000101
# DIS   0.000080  0.000105  0.000173  0.000073  0.000052  0.000086
# IBM   0.000076  0.000088  0.000073  0.000154  0.000047  0.000088
# KO    0.000040  0.000057  0.000052  0.000047  0.000085  0.000051
# MSFT  0.000107  0.000101  0.000086  0.000088  0.000051  0.000213

# %%
ret.corr()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT
# AAPL  1.000000  0.409917  0.373137  0.374747  0.266943  0.447157
# BA    0.409917  1.000000  0.518342  0.459294  0.401417  0.446867
# DIS   0.373137  0.518342  1.000000  0.448732  0.432673  0.450880
# IBM   0.374747  0.459294  0.448732  1.000000  0.407401  0.485883
# KO    0.266943  0.401417  0.432673  0.407401  1.000000  0.378181
# MSFT  0.447157  0.446867  0.450880  0.485883  0.378181  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,7))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws={"size":15}, vmax = 0.6)
plt.show()

# %% [markdown]
# ## Simple Returns vs. Log Returns

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(index = [2016, 2017, 2018], data = [100, 50, 95], columns = ["Price"])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simple_returns = df.pct_change().dropna()
simple_returns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simple_returns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100 * 1.2 * 1.2 # 2018년의 예상가 -> 단순 수익과 평균 수익의 함정
# Out:
# 144.0

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
np.log(df / df.shift(1))
# Out:
#          Price
# 2016       NaN
# 2017 -0.693147
# 2018  0.641854

# %%
log_returns = np.log(df / df.shift(1)).dropna()
log_returns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
log_returns.mean() # 로그 수익률의 평균
# Out:
# Price   -0.025647
# dtype: float64

# %%
100 * np.exp(2 * log_returns.mean()) # 100 * e^(2 * 로그 수익률의 평균)
# Out:
# Price    95.0
# dtype: float64

# %% [markdown]
# ## Importing Financial Data from Excel

# %%
import pandas as pd

# %%
pd.read_excel("SP500.xls").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12107 entries, 0 to 12106
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       12107 non-null  datetime64[ns]
#  1   Open       12107 non-null  float64
#  2   High       12107 non-null  float64
#  3   Low        12107 non-null  float64
#  4   Close      12107 non-null  float64
#  5   Adj Close  12107 non-null  float64
#  6   Volume     12107 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 662.2 KB

# %%
pd.read_excel("SP500.xls", parse_dates= ["Date"], index_col = "Date")
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1970-12-31    92.269997    92.790001    91.360001    92.150002    92.150002
# 1971-01-04    92.150002    92.190002    90.639999    91.150002    91.150002
# 1971-01-05    91.150002    92.279999    90.690002    91.800003    91.800003
# 1971-01-06    91.800003    93.000000    91.500000    92.349998    92.349998
# 1971-01-07    92.349998    93.260002    91.750000    92.379997    92.379997
# ...                 ...          ...          ...          ...          ...
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990  2485.739990
#
#                 Volume
# Date
# 1970-12-31    13390000
# 1971-01-04    10010000
# 1971-01-05    12600000
# 1971-01-06    16960000
# 1971-01-07    16460000
# ...                ...
# 2018-12-21  -980924592
# 2018-12-24 -1681037296
# 2018-12-26   -60977296
# 2018-12-27  -198357296
# 2018-12-28  -592347296
#
# [12107 rows x 6 columns]

# %%
pd.read_excel("SP500.xls", parse_dates= ["Date"], index_col = "Date", usecols = "A, C:E")
# Out:
#                    High          Low        Close
# Date
# 1970-12-31    92.790001    91.360001    92.150002
# 1971-01-04    92.190002    90.639999    91.150002
# 1971-01-05    92.279999    90.690002    91.800003
# 1971-01-06    93.000000    91.500000    92.349998
# 1971-01-07    93.260002    91.750000    92.379997
# ...                 ...          ...          ...
# 2018-12-21  2504.409912  2408.550049  2416.620117
# 2018-12-24  2410.340088  2351.100098  2351.100098
# 2018-12-26  2467.760010  2346.580078  2467.699951
# 2018-12-27  2489.100098  2397.939941  2488.830078
# 2018-12-28  2520.270020  2472.889893  2485.739990
#
# [12107 rows x 3 columns]

# %%
pd.read_excel("SP500.xls", sheet_name= "Sales")
# Out:
#   Unnamed: 0      City  Sales
# 0       Mike  New York     25
# 1        Jim    Boston     43
# 2     Steven    London     76
# 3        Joe    Madrid     12
# 4        Tom     Paris     89

# %%
SP500 = pd.read_excel("SP500.xls", parse_dates= ["Date"], index_col = "Date", usecols= "A:E")

# %%
SP500.head()
# Out:
#                  Open       High        Low      Close
# Date
# 1970-12-31  92.269997  92.790001  91.360001  92.150002
# 1971-01-04  92.150002  92.190002  90.639999  91.150002
# 1971-01-05  91.150002  92.279999  90.690002  91.800003
# 1971-01-06  91.800003  93.000000  91.500000  92.349998
# 1971-01-07  92.349998  93.260002  91.750000  92.379997

# %%
SP500.tail()
# Out:
#                    Open         High          Low        Close
# Date
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990

# %%
SP500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12107 entries, 1970-12-31 to 2018-12-28
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    12107 non-null  float64
#  1   High    12107 non-null  float64
#  2   Low     12107 non-null  float64
#  3   Close   12107 non-null  float64
# dtypes: float64(4)
# memory usage: 472.9 KB

# %%
SP500.to_csv("SP500.csv")

# %%
SP500.to_excel("SP500_red.xls")
# Out:
# /var/folders/k8/xm42xp_16cs6fgtvp6ymr9l40000gn/T/ipykernel_17292/1964959483.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   SP500.to_excel("SP500_red.xls")

# %% [markdown]
# ## Simple Moving Averages (SMA) with rolling()

# %%
import pandas as pd
import matplotlib.pyplot as plt 
plt.style.use("seaborn")
# Out:
# /var/folders/k8/xm42xp_16cs6fgtvp6ymr9l40000gn/T/ipykernel_17292/1547994382.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
SP500 = pd.read_csv("SP500.csv", parse_dates = ["Date"], index_col = "Date")

# %%
SP500.head()
# Out:
#                  Open       High        Low      Close
# Date
# 1970-12-31  92.269997  92.790001  91.360001  92.150002
# 1971-01-04  92.150002  92.190002  90.639999  91.150002
# 1971-01-05  91.150002  92.279999  90.690002  91.800003
# 1971-01-06  91.800003  93.000000  91.500000  92.349998
# 1971-01-07  92.349998  93.260002  91.750000  92.379997

# %%
SP500.tail()
# Out:
#                    Open         High          Low        Close
# Date
# 2018-12-21  2465.379883  2504.409912  2408.550049  2416.620117
# 2018-12-24  2400.560059  2410.340088  2351.100098  2351.100098
# 2018-12-26  2363.120117  2467.760010  2346.580078  2467.699951
# 2018-12-27  2442.500000  2489.100098  2397.939941  2488.830078
# 2018-12-28  2498.770020  2520.270020  2472.889893  2485.739990

# %%
SP500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12107 entries, 1970-12-31 to 2018-12-28
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    12107 non-null  float64
#  1   High    12107 non-null  float64
#  2   Low     12107 non-null  float64
#  3   Close   12107 non-null  float64
# dtypes: float64(4)
# memory usage: 472.9 KB

# %%
SP500 = SP500.Close.to_frame()

# %%
SP500.head()
# Out:
#                 Close
# Date
# 1970-12-31  92.150002
# 1971-01-04  91.150002
# 1971-01-05  91.800003
# 1971-01-06  92.349998
# 1971-01-07  92.379997

# %%
SP500.plot(figsize = (12,8), fontsize= 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
SP500 = SP500.loc["2008-12-31":"2018-12-31"].copy()

# %%
SP500.rolling(window = 10)
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
type(SP500.rolling(window = 10))
# Out:
# pandas.core.window.rolling.Rolling

# %%
SP500.head(15)
# Out:
#                  Close
# Date
# 2008-12-31  903.250000
# 2009-01-02  931.799988
# 2009-01-05  927.450012
# 2009-01-06  934.700012
# 2009-01-07  906.650024
# 2009-01-08  909.729980
# 2009-01-09  890.349976
# 2009-01-12  870.260010
# 2009-01-13  871.789978
# 2009-01-14  842.619995
# 2009-01-15  843.739990
# 2009-01-16  850.119995
# 2009-01-20  805.219971
# 2009-01-21  840.239990
# 2009-01-22  827.500000

# %%
SP500.rolling(window = 10).mean()
# Out:
#                   Close
# Date
# 2008-12-31          NaN
# 2009-01-02          NaN
# 2009-01-05          NaN
# 2009-01-06          NaN
# 2009-01-07          NaN
# ...                 ...
# 2018-12-21  2565.915991
# 2018-12-24  2537.254004
# 2018-12-26  2520.345996
# 2018-12-27  2504.121997
# 2018-12-28  2487.641992
#
# [2516 rows x 1 columns]

# %%
SP500.rolling(window = 10).median()
# Out:
#                   Close
# Date
# 2008-12-31          NaN
# 2009-01-02          NaN
# 2009-01-05          NaN
# 2009-01-06          NaN
# 2009-01-07          NaN
# ...                 ...
# 2018-12-21  2573.054931
# 2018-12-24  2546.049926
# 2018-12-26  2526.449951
# 2018-12-27  2497.895019
# 2018-12-28  2487.285034
#
# [2516 rows x 1 columns]

# %%
SP500.rolling(window = 10, min_periods=5).mean()
# Out:
#                   Close
# Date
# 2008-12-31          NaN
# 2009-01-02          NaN
# 2009-01-05          NaN
# 2009-01-06          NaN
# 2009-01-07   920.770007
# ...                 ...
# 2018-12-21  2565.915991
# 2018-12-24  2537.254004
# 2018-12-26  2520.345996
# 2018-12-27  2504.121997
# 2018-12-28  2487.641992
#
# [2516 rows x 1 columns]

# %% [markdown]
# ## Momentum Trading Strategies with SMAs

# %%
SP500.head()
# Out:
#                  Close
# Date
# 2008-12-31  903.250000
# 2009-01-02  931.799988
# 2009-01-05  927.450012
# 2009-01-06  934.700012
# 2009-01-07  906.650024

# %%
SP500.tail()
# Out:
#                   Close
# Date
# 2018-12-21  2416.620117
# 2018-12-24  2351.100098
# 2018-12-26  2467.699951
# 2018-12-27  2488.830078
# 2018-12-28  2485.739990

# %%
SP500["SMA50"] = SP500.rolling(window = 50, min_periods=50).mean()

# %%
SP500
# Out:
#                   Close        SMA50
# Date
# 2008-12-31   903.250000          NaN
# 2009-01-02   931.799988          NaN
# 2009-01-05   927.450012          NaN
# 2009-01-06   934.700012          NaN
# 2009-01-07   906.650024          NaN
# ...                 ...          ...
# 2018-12-21  2416.620117  2692.420195
# 2018-12-24  2351.100098  2684.874795
# 2018-12-26  2467.699951  2678.886196
# 2018-12-27  2488.830078  2673.646997
# 2018-12-28  2485.739990  2667.163398
#
# [2516 rows x 2 columns]

# %%
SP500.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
SP500["SMA200"] = SP500.Close.rolling(window = 200).mean()

# %%
SP500.tail()
# Out:
#                   Close        SMA50      SMA200
# Date
# 2018-12-21  2416.620117  2692.420195  2753.65980
# 2018-12-24  2351.100098  2684.874795  2751.48245
# 2018-12-26  2467.699951  2678.886196  2749.90585
# 2018-12-27  2488.830078  2673.646997  2748.52345
# 2018-12-28  2485.739990  2667.163398  2747.20475

# %%
SP500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2008-12-31 to 2018-12-28
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2516 non-null   float64
#  1   SMA50   2467 non-null   float64
#  2   SMA200  2317 non-null   float64
# dtypes: float64(3)
# memory usage: 78.6 KB

# %%
SP500.plot(figsize = (15,10), fontsize= 15)
plt.legend(fontsize = 15)
plt.show()

# %%
SP500.iloc[:,-2:].plot(figsize = (15,10), fontsize= 15)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# ## Exponentially-weighted Moving Averages (EWMA)

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# /var/folders/k8/xm42xp_16cs6fgtvp6ymr9l40000gn/T/ipykernel_17292/430243705.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
SP500 = pd.read_csv("SP500.csv", parse_dates= ["Date"], index_col= "Date", usecols= ["Date", "Close"])

# %%
SP500.head()
# Out:
#                 Close
# Date
# 1970-12-31  92.150002
# 1971-01-04  91.150002
# 1971-01-05  91.800003
# 1971-01-06  92.349998
# 1971-01-07  92.379997

# %%
SP500 = SP500.loc["2008-12-31":"2018-12-31"].copy()

# %%
SP500.Close.rolling(window = 10).mean()
# Out:
# Date
# 2008-12-31            NaN
# 2009-01-02            NaN
# 2009-01-05            NaN
# 2009-01-06            NaN
# 2009-01-07            NaN
#                  ...
# 2018-12-21    2565.915991
# 2018-12-24    2537.254004
# 2018-12-26    2520.345996
# 2018-12-27    2504.121997
# 2018-12-28    2487.641992
# Name: Close, Length: 2516, dtype: float64

# %%
SP500.Close.ewm(span = 10, min_periods= 10).mean()
# Out:
# Date
# 2008-12-31            NaN
# 2009-01-02            NaN
# 2009-01-05            NaN
# 2009-01-06            NaN
# 2009-01-07            NaN
#                  ...
# 2018-12-21    2547.124619
# 2018-12-24    2511.483797
# 2018-12-26    2503.523098
# 2018-12-27    2500.851640
# 2018-12-28    2498.104067
# Name: Close, Length: 2516, dtype: float64

# %%
SP500["SMA"] = SP500.Close.rolling(window = 100).mean()
SP500["EMA"] = SP500.Close.ewm(span = 100, min_periods= 100).mean()

# %%
SP500
# Out:
#                   Close          SMA          EMA
# Date
# 2008-12-31   903.250000          NaN          NaN
# 2009-01-02   931.799988          NaN          NaN
# 2009-01-05   927.450012          NaN          NaN
# 2009-01-06   934.700012          NaN          NaN
# 2009-01-07   906.650024          NaN          NaN
# ...                 ...          ...          ...
# 2018-12-21  2416.620117  2785.905496  2732.088580
# 2018-12-24  2351.100098  2781.282896  2724.544253
# 2018-12-26  2467.699951  2777.687695  2719.458228
# 2018-12-27  2488.830078  2774.172495  2714.891334
# 2018-12-28  2485.739990  2770.525896  2710.353683
#
# [2516 rows x 3 columns]

# %%
SP500.iloc[:,-2:].plot(figsize = (15,10), fontsize =15)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# ### Merging Time Series

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0]).Close

# %%
stocks.head()
# Out:
#                 AAPL         BA        DIS         IBM         KO       MSFT
# Date
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  28.520000  30.950001
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  28.174999  30.959999
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  28.165001  30.770000
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  28.094999  30.450001
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  27.575001  30.660000

# %%
aapl = stocks.loc["2010-01-01" : "2014-12-31", "AAPL"].to_frame()
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
ba = stocks.loc["2012-01-01" : "2016-12-31", "BA"].to_frame()
ba.head()
# Out:
#                    BA
# Date
# 2012-01-03  74.220001
# 2012-01-04  74.330002
# 2012-01-05  73.529999
# 2012-01-06  73.980003
# 2012-01-09  74.529999

# %%
aapl["BA"] = ba.BA

# %%
aapl.head()
# Out:
#                 AAPL  BA
# Date
# 2010-01-04  7.643214 NaN
# 2010-01-05  7.656429 NaN
# 2010-01-06  7.534643 NaN
# 2010-01-07  7.520714 NaN
# 2010-01-08  7.570714 NaN

# %%
aapl.tail()
# Out:
#                  AAPL          BA
# Date
# 2014-12-24  28.002501  131.240005
# 2014-12-26  28.497499  131.630005
# 2014-12-29  28.477501  132.289993
# 2014-12-30  28.129999  131.830002
# 2014-12-31  27.594999  129.979996

# %%
aapl.dropna()
# Out:
#                  AAPL          BA
# Date
# 2012-01-03  14.686786   74.220001
# 2012-01-04  14.765714   74.330002
# 2012-01-05  14.929643   73.529999
# 2012-01-06  15.085714   73.980003
# 2012-01-09  15.061786   74.529999
# ...               ...         ...
# 2014-12-24  28.002501  131.240005
# 2014-12-26  28.497499  131.630005
# 2014-12-29  28.477501  132.289993
# 2014-12-30  28.129999  131.830002
# 2014-12-31  27.594999  129.979996
#
# [754 rows x 2 columns]

# %%
ba.reindex(aapl.index).dropna()
# Out:
#                     BA
# Date
# 2012-01-03   74.220001
# 2012-01-04   74.330002
# 2012-01-05   73.529999
# 2012-01-06   73.980003
# 2012-01-09   74.529999
# ...                ...
# 2014-12-24  131.240005
# 2014-12-26  131.630005
# 2014-12-29  132.289993
# 2014-12-30  131.830002
# 2014-12-31  129.979996
#
# [754 rows x 1 columns]

# %%
dis = stocks.loc["2010-01-01" : "2016-12-31", "DIS"].resample("W-Fri").last().to_frame()
dis.head()
# Out:
#                   DIS
# Date
# 2010-01-08  31.879999
# 2010-01-15  30.600000
# 2010-01-22  29.980000
# 2010-01-29  29.549999
# 2010-02-05  29.540001

# %%
aapl["DIS"] = dis.DIS
aapl.head()
# Out:
#                 AAPL  BA        DIS
# Date
# 2010-01-04  7.643214 NaN        NaN
# 2010-01-05  7.656429 NaN        NaN
# 2010-01-06  7.534643 NaN        NaN
# 2010-01-07  7.520714 NaN        NaN
# 2010-01-08  7.570714 NaN  31.879999

# %%
aapl.reindex(dis.index)
# Out:
#                 AAPL  BA        DIS
# Date
# 2010-01-08  7.570714 NaN  31.879999
# 2010-01-15  7.354643 NaN  30.600000
# 2010-01-22  7.062500 NaN  29.980000
# 2010-01-29  6.859286 NaN  29.549999
# 2010-02-05  6.980714 NaN  29.540001
# ...              ...  ..        ...
# 2016-12-02       NaN NaN        NaN
# 2016-12-09       NaN NaN        NaN
# 2016-12-16       NaN NaN        NaN
# 2016-12-23       NaN NaN        NaN
# 2016-12-30       NaN NaN        NaN
#
# [365 rows x 3 columns]
